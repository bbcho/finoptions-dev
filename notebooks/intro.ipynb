# %%
import pandas_datareader as data

# %%
import energyderivatives as ed
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f3be0fa2c62d> in <module>
# ----> 1 import energyderivatives as ed
#
# ModuleNotFoundError: No module named 'energyderivatives'
